# %%
# !nvidia-smi
# Out:
# Thu Jan  2 20:36:55 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.36                 Driver Version: 566.36         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   43C    P0             16W /   50W |       0MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %pip install ultralytics
# %pip install ultralytics opencv-python

from IPython import display
# display.clear_output()

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.23  Python-3.12.8 torch-2.5.0+cpu CPU (Intel Core(TM) i5-10300H 2.50GHz)
# Setup complete  (8 CPUs, 15.8 GB RAM, 372.2/453.4 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=detect mode=train data=C:/Users/ibaib/Videos/final/data.yaml model=yolov8s.pt epochs=45 imgsz=300 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.56 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.23 🚀 Python-3.12.8 torch-2.5.0+cpu CPU (Intel Core(TM) i5-10300H 2.50GHz)
# ...

# %%
#check label
# !yolo data=data.yaml mode=check

# %%
# !yolo task=detect mode=val model=C:/Users/ibaib/Videos/final/runs/detect/train4/weights/best.pt data=data.yaml save=true
# Out:
# Ultralytics 8.3.23 🚀 Python-3.12.8 torch-2.5.0+cpu CPU (Intel Core(TM) i5-10300H 2.50GHz)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                    all         37         18      0.777      0.889        0.9      0.512
# Speed: 0.7ms preprocess, 48.5ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to runs\detect\val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning C:\Users\ibaib\Videos\final\valid\labels.cache... 37 images, 19 backgrounds, 0 corrupt: 100%|██████████| 37/37 [00:00<?, ?it/s]
# val: Scanning C:\Users\ibaib\Videos\final\valid\labels.cache... 37 images, 19 backgrounds, 0 corrupt: 100%|██████████| 37/37 [00:00<?, ?it/s]
#
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):   0%|          | 0/3 [00:00<?, ?it/s]
# ...
